# %%
import pandas, seaborn
df = pandas.read_csv('datasets/college_data.csv')

# %%
expense = df['Tuition and fees, 2010-11']+df['Tuition and fees, 2011-12']+df['Tuition and fees, 2012-13']+df['Tuition and fees, 2013-14']
df['expense'] = expense/4
df['academic_performance'] = df['ACT Composite 75th percentile score']

# %%
a = df[df['State abbreviation'] == 'Tennessee']
a
# Out:
#       ID number                                     Name  year    ZIP code  \
# 1222     219578                          Aquinas College  2013       37205
# 1223     219602             Austin Peay State University  2013       37044
# 1224     219709                       Belmont University  2013  37212-3757
# 1225     219718                        Bethel University  2013       38201
# 1226     219790                     Bryan College-Dayton  2013  37321-7000
# 1227     219806                 Carson-Newman University  2013       37760
# 1228     219833            Christian Brothers University  2013       38104
# 1229     219949                    Cumberland University  2013       37087
# 1230     219976                      Lipscomb University  2013  37204-3951
# 1231     220075          East Tennessee State University  2013  37614-0000
# 1232     220181                          Fisk University  2013  37208-4501
# ...

# %%
a.plot.scatter(x='academic_performance', y='expense')
# Out:
# <AxesSubplot:xlabel='academic_performance', ylabel='expense'>

# %% [markdown]
# ---
#
# **Question 3**
#
# What are the top-3 most expensive univeristy/college in the state of Tennessee? Do they have the best academic performance?  Answer and show your work/code.

# %%
a[['expense', 'State abbreviation', 'Name', 'academic_performance']].sort_values(by='expense', ascending=False)
# Out:
#        expense State abbreviation                                     Name  \
# 1257  41589.50          Tennessee                    Vanderbilt University
# 1245  37232.50          Tennessee                           Rhodes College
# 1246  34656.00          Tennessee      Sewanee-The University of the South
# 1241  30262.75          Tennessee                        Maryville College
# 1228  26620.00          Tennessee            Christian Brothers University
# 1244  25864.00          Tennessee                         Milligan College
# 1224  25537.50          Tennessee                       Belmont University
# 1256  24737.50          Tennessee                         Union University
# 1235  24220.00          Tennessee                          King University
# 1230  24085.50          Tennessee                      Lipscomb University
# 1227  22172.00          Tennessee                 Carson-Newman University
# ...

# %% [markdown]
# I decided to grab the Name, state(not needed), academic_performance, and expense to see and sort by highest to lowest expense. From this you can see that base on tennessee, expense does mean better grades.

# %%
a[['expense', 'State abbreviation', 'Name', 'academic_performance']].sort_values(by='academic_performance', ascending=False)
# Out:
#        expense State abbreviation                                     Name  \
# 1257  41589.50          Tennessee                    Vanderbilt University
# 1245  37232.50          Tennessee                           Rhodes College
# 1246  34656.00          Tennessee      Sewanee-The University of the South
# 1224  25537.50          Tennessee                       Belmont University
# 1256  24737.50          Tennessee                         Union University
# 1250   9016.00          Tennessee    The University of Tennessee-Knoxville
# 1230  24085.50          Tennessee                      Lipscomb University
# 1234  18484.75          Tennessee                Freed-Hardeman University
# 1238  13005.00          Tennessee                           Lee University
# 1222  19432.50          Tennessee                          Aquinas College
# 1228  26620.00          Tennessee            Christian Brothers University
# ...

# %% [markdown]
# From this we see that Univeristy of Memphis is tied for 18th.

# %%
a[['expense', 'State abbreviation', 'Name', 'academic_performance']].sort_values(by='expense', ascending=True)
# Out:
#        expense State abbreviation                                     Name  \
# 1252   6179.00          Tennessee               Tennessee State University
# 1253   6497.25          Tennessee       Tennessee Technological University
# 1223   6501.00          Tennessee             Austin Peay State University
# 1231   6514.50          Tennessee          East Tennessee State University
# 1251   6865.50          Tennessee       The University of Tennessee-Martin
# 1249   6886.50          Tennessee  The University of Tennessee-Chattanooga
# 1243   6952.00          Tennessee        Middle Tennessee State University
# 1242   7596.50          Tennessee                    University of Memphis
# 1236   8490.00          Tennessee                             Lane College
# 1250   9016.00          Tennessee    The University of Tennessee-Knoxville
# 1237  10489.00          Tennessee                    Le Moyne-Owen College
# ...

# %% [markdown]
# From the above, We can tell that University of Memphis is 8th lowest for expense.

# %% [markdown]
# Firstly, decided to print out the columns to find private or public column (it was Control of institution)

# %%
# for x in df.columns:
#     print(x)

# %%
# df.groupby(by='Control of institution').count()
b = df.groupby(by='Control of institution').mean()
b[['expense', 'academic_performance']]
# Out:
#                              expense  academic_performance
# Control of institution
# Private not-for-profit  26582.516809             26.093496
# Public                   7783.163653             24.737527

# %% [markdown]
# From above, we see that Private is more expensive and performs better academically. I would personally go public since price of public is cheaper and the performance is only marginally small.

# %% [markdown]
# So initally think i would find Memphis expense, then do 5 percent increase and decrease and set the filter to that.

# %%
a[a['Name'] == 'University of Memphis']['expense']
# Out:
# 1242    7596.5
# Name: expense, dtype: float64

# %% [markdown]
# Memphis expense is 7596.5

# %%
7596.5 * .05
# Out:
# 379.82500000000005

# %%
7596.5 + 379.83
# Out:
# 7976.33

# %%
7596.5 - 379.83
# Out:
# 7216.67

# %%
df[(df['expense'] < 7976.34) &(df['expense'] > 7216.66)]
# Out:
#       ID number                               Name  year    ZIP code  \
# 2        100690                 Amridge University  2013  36117-3553
# 4        100724           Alabama State University  2013  36104-0271
# 7        100830    Auburn University at Montgomery  2013  36117-3596
# 10       101073          Concordia College Alabama  2013       36701
# 41       106306           Arkansas Baptist College  2013  72202-6068
# ...         ...                                ...   ...         ...
# 1492     404073      Baker College of Auburn Hills  2013  48326-2642
# 1493     404082  Baker College of Clinton Township  2013       48035
# 1494     404648          Baker College of Cadillac  2013  49601-9600
# 1497     414160           Baker College of Jackson  2013  49202-1290
# 1512     444167        Baker College of Allen Park  2013       48101
#
#                                  Highest degree offered        County name  \
# ...

# %% [markdown]
# From above we can see all colleges with expense within 5 percent of memphis expense. This already shows count at 74, but to find it by code is using .count() after.

# %% [markdown]
# Can use the code above but sort by academic_performance

# %%
df[(df['expense'] < 7976.34) &(df['expense'] > 7216.66)].sort_values(by='academic_performance', ascending=False)
# Out:
#       ID number                                               Name  year  \
# 930      199120        University of North Carolina at Chapel Hill  2013
# 871      196079                                 SUNY at Binghamton  2013
# 66       110422  California Polytechnic State University-San Lu...  2013
# 873      196097                             Stony Brook University  2013
# 934      199193         North Carolina State University at Raleigh  2013
# ...         ...                                                ...   ...
# 1492     404073                      Baker College of Auburn Hills  2013
# 1493     404082                  Baker College of Clinton Township  2013
# 1494     404648                          Baker College of Cadillac  2013
# 1497     414160                           Baker College of Jackson  2013
# 1512     444167                        Baker College of Allen Park  2013
#
#         ZIP code                             Highest degree offered  \
# ...

# %% [markdown]
# Answer is University of North Carolina at Chapel Hill with peformance of 32.
